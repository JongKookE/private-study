# %%
import numpy as np  # numpy 라이브러리를 np로 import
import pandas as pd  # pandas 라이브러리를 pd로 import
import seaborn as sns  # seaborn 라이브러리를 sns로 import
import matplotlib.pyplot as plt  # matplotlib 라이브러리의 pyplot 모듈을 plt로 import

# %%
raw = pd.read_csv("kaggle_survey_2020_responses.csv", low_memory=False)
raw.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                    Master’s degree
# 3                                  Bachelor’s degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                            Student
# 2                                      Data Engineer
# 3                                  Software Engineer
# 4                                     Data Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                         5-10 years
# 3                                        10-20 years
# 4                                         5-10 years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                             Python
# 3                                                NaN
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                  R
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  ...  \
# 0  What programming languages do you use on a reg...  ...
# 1                                                SQL  ...
# 2                                                SQL  ...
# 3                                                NaN  ...
# 4                                                SQL  ...
#
#                                         Q35_B_Part_2  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                       TensorBoard
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q35_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                               None
# 4                                                NaN
#
#                                          Q35_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 355 columns]

# %%
question = raw.iloc[0]
question
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
#                                                              ...
# Q35_B_Part_7                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_8                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_9                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_10                          In the next 2 years, do you hope to become mor...
# Q35_B_OTHER                            In the next 2 years, do you hope to become mor...
# Name: 0, Length: 355, dtype: object

# %% [markdown]
# # iloc와 loc의 차이
#
# 'iloc' 행과 열의 위치(integer position)을 기반으로 데이터를 선택
# 'loc' 행의 라벨을 기반으로 데이터를 선택

# %%
answer = raw.drop([0]) #0번째 인덱스만 제거하여 질문에 대한 답변만 저장
answer
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 1                                    1838  35-39    Man
# 2                                  289287  30-34    Man
# 3                                     860  35-39    Man
# 4                                     507  30-34    Man
# 5                                      78  30-34    Man
# ...                                   ...    ...    ...
# 20032                                 126  18-21    Man
# 20033                                 566  55-59  Woman
# 20034                                 238  30-34    Man
# 20035                                 625  22-24    Man
# 20036                                1031  22-24    Man
#
#                                                       Q3  \
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# 5                                                  Japan
# ...                                                  ...
# 20032                                             Turkey
# 20033  United Kingdom of Great Britain and Northern I...
# 20034                                             Brazil
# 20035                                              India
# 20036                                           Pakistan
#
#                                                       Q4  \
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# 5                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                               Q5           Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 1                        Student   5-10 years    Python         R       SQL
# 2                  Data Engineer   5-10 years    Python         R       SQL
# 3              Software Engineer  10-20 years       NaN       NaN       NaN
# 4                 Data Scientist   5-10 years    Python       NaN       SQL
# 5              Software Engineer    3-5 years    Python       NaN       NaN
# ...                          ...          ...       ...       ...       ...
# 20032                        NaN          NaN       NaN       NaN       NaN
# 20033     Currently not employed    20+ years    Python       NaN       NaN
# 20034         Research Scientist    < 1 years    Python       NaN       NaN
# 20035          Software Engineer    3-5 years    Python       NaN       SQL
# 20036  Machine Learning Engineer    < 1 years    Python       NaN       NaN
#
#        ...        Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4   Q35_B_Part_5  \
# 1      ...                 NaN          NaN          NaN   TensorBoard
# 2      ...                 NaN          NaN          NaN            NaN
# 3      ...                 NaN          NaN          NaN            NaN
# 4      ...                 NaN          NaN          NaN            NaN
# 5      ...                 NaN          NaN          NaN            NaN
# ...    ...                 ...          ...          ...            ...
# 20032  ...                 NaN          NaN          NaN            NaN
# 20033  ...                 NaN          NaN          NaN            NaN
# 20034  ...                 NaN          NaN          NaN            NaN
# 20035  ...   Weights & Biases           NaN          NaN   TensorBoard
# 20036  ...   Weights & Biases           NaN          NaN            NaN
#
#       Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10  \
# 1              NaN          NaN          NaN          NaN           NaN
# 2              NaN          NaN          NaN          NaN           NaN
# 3              NaN          NaN          NaN          NaN          None
# 4              NaN          NaN          NaN          NaN           NaN
# 5              NaN          NaN          NaN          NaN           NaN
# ...            ...          ...          ...          ...           ...
# 20032          NaN          NaN          NaN          NaN           NaN
# 20033          NaN          NaN          NaN          NaN          None
# 20034          NaN          NaN          NaN          NaN           NaN
# 20035          NaN          NaN      Trains           NaN           NaN
# 20036          NaN          NaN      Trains           NaN           NaN
#
#       Q35_B_OTHER
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# ...           ...
# 20032         NaN
# 20033         NaN
# 20034         NaN
# 20035         NaN
# 20036         NaN
#
# [20036 rows x 355 columns]

# %%
answer.shape
# Out:
# (20036, 355)

# %%
question_no2 = "Q2"
Q2 = answer[question_no2].value_counts()
Q2
# Out:
# Man                        15789
# Woman                       3878
# Prefer not to say            263
# Prefer to self-describe       54
# Nonbinary                     52
# Name: Q2, dtype: int64

# %%
sns.countplot(data=answer, y = question_no2).set_title(question[question_no2])
# Out:
# Text(0.5, 1.0, 'What is your gender? - Selected Choice')

# %%
sns.barplot(x = Q2.index, y=Q2.values)
sns.set_style("whitegrid")
plt.title(question[question_no2])
plt.show()

# %%
ManWo = ["Man", "Woman"]

# %%
q1q2 = pd.crosstab(answer["Q1"], answer["Q2"])

q1q2[ManWo].plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='Q1'>

# %% [markdown]
# rot=0은 x축 레이블을 회전하지않고 수평으로 유지하도록 저장
#
# ![image.png](attachment:image.png)
# <br>
# rot = 90이 되니 x축이 회전한 모습

# %%
q1q2[ManWo].sort_index(ascending=False).plot.barh(title = "Age & Gender")
# Out:
# <AxesSubplot:title={'center':'Age & Gender'}, ylabel='Q1'>

# %%
order_list = [x for x in answer["Q5"]]
order_list = set(order_list)

real_order_list = list(order_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\pythonWorkSpace\kaggle\kaggle_survey_EDA.ipynb Cell 14 in 5
#       <a href='vscode-notebook-cell:/c%3A/pythonWorkSpace/kaggle/kaggle_survey_EDA.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> order_list = set(order_list)
#       <a href='vscode-notebook-cell:/c%3A/pythonWorkSpace/kaggle/kaggle_survey_EDA.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> real_order_list = list(order_list)
# ----> <a href='vscode-notebook-cell:/c%3A/pythonWorkSpace/kaggle/kaggle_survey_EDA.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> real_order_list.remove('nan')
#
# ValueError: list.remove(x): x not in list

# %%
real_order_list
# Out:
# [nan,
#  'Data Scientist',
#  'Statistician',
#  'DBA/Database Engineer',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Student',
#  'Data Engineer',
#  'Business Analyst',
#  'Research Scientist',
#  'Software Engineer',
#  'Currently not employed',
#  'Product/Project Manager',
#  'Other']

# %%
def show_countplot_by_question_number(qno, fsize = (10,6), order = None, palette = None):
    if not order:
        order = answer[qno].value_counts().index
    plt.figure(figsize = fsize)
    sns.countplot(data=answer, y = qno, order = order, palette=palette).set_title(question[qno])


show_countplot_by_question_number("Q5", palette="Greens_r", order = real_order_list)

# %% [markdown]
# ### order
# 카테고리를 정렬하는 방법을 지정하는 매개변수
# <br>
# order = ["카테고리1", "카테고리2", "카테고리3"]
# <br>
# order라는 리스트의 순서대로 정렬이 됨
# <br>
# 잘 사용되면 value_counts().sort()등을 사용하지 않아도 될수도..?
